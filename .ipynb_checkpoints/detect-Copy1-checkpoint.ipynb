# %% [markdown]
# ### import

# %%
# 標準ライブラリ
import os
import datetime as dt
from datetime import timedelta
from statistics import mean, median,variance,stdev
import itertools
# サードパーティライブラリ
import numpy as np
import pandas as pd
import burst_detection as bd

# %% [markdown]
# ### 連続した日付データ作成 date_range()
# 閉区間[start, end]の範囲で出力する

# %%
def date_range(start, end):
    for n in range((end - start).days + 1):
        yield start + timedelta(n)

# %% [markdown]
# ## 変数 定数

# %%
# gamma: 
# 基本的に値が高ければ高いほど、バーストが立ち上がりにくくなるパラメータなのでこれの調整の優先度は低いと思います。
# とりあえずgamma＝1とかに設定しておくのがいいです。
# s: 
# 値が高ければ高いほど、バーストが分割される傾向にあるので、1.1~2の範囲で試してみるのがいいかも
param_s = 1.5# 2.0
param_gamma = 1.0 # 1.0

RESULT_DIR = "/Users/daigo/workspace/koyo/result/"
total_count_dir = RESULT_DIR + "total_count/"

rtweets_count_dir = RESULT_DIR + "rtweets_count_koyo_de_icho/"
# rtweets_count_dir = RESULT_DIR + "rtweets_count/"

out_path = f"{RESULT_DIR}graph/koyo_de_icho/s{param_s}gamma{param_gamma}/"
# out_path = f"{RESULT_DIR}graph/s{param_s}gamma{param_gamma}/"
# out_path = f"{RESULT_DIR}graph/uniq_icho/s{param_s}gamma{param_gamma}/"
# out_path = f"{RESULT_DIR}graph/sakura/s{param_s}gamma{param_gamma}/"
# sakura を推定するときはout_path注意。

RATES = range(10, 101, 10)
prefs = ['tk', 'hk', 'is'] # ['tk', 'hk', 'is']
flags = ["icho"]  # ["icho", "kaede", "sonota", "koyo", "jumoku"] , "sakura"

# %%
CORRECTS = {
    "tk": {
        "kaede": {"start": dt.date(2015, 12, 4), "end": dt.date(2015, 12, 12)},
        "icho": {"start": dt.date(2015, 11, 30), "end": dt.date(2015, 12, 11)},
        "sakura": {"start": dt.date(2015, 3, 23), "end": dt.date(2015, 3, 29)}
    },
    "hk": {
        "kaede": {"start": dt.date(2015, 10, 29), "end": dt.date(2015, 11, 29)},
        "icho": {"start": dt.date(2015, 11, 2), "end": dt.date(2015, 11, 12)},
        "sakura": {"start": dt.date(2015, 4, 22), "end": dt.date(2015, 4, 26)}
    },
    "is": {
        "kaede": {"start": dt.date(2015, 11, 22), "end": dt.date(2015, 12, 3)},
        "icho": {"start": dt.date(2015, 11, 4), "end": dt.date(2015, 11, 10)},
        "sakura": {"start": dt.date(2015, 3, 31), "end": dt.date(2015, 4, 4)}
    }
}

end = dt.date(2015, 12, 31)

sakura_dates = [date for date in date_range(dt.date(2015, 2, 17), end) ]
koyo_short_dates = [date for date in date_range(dt.date(2015, 10, 1), end)]                  
koyo_long_dates = [date for date in date_range(dt.date(2015, 8, 15), end)]

# dates = koyo_long_dates  # ここを変えれば期間が変わる（ようにする予定）

# %% [markdown]
# ## 関数宣言

# %% [markdown]
# ### バースト検出

# %%
def burst_detection(target_counts, total_counts):
    #number of target events at each time point
    r = np.array(target_counts, dtype=float)
    
    #total number of events at each time point
    d = np.array(total_counts, dtype=float)
    
    #number of time points
    n = len(r)

    q, d, r, p = bd.burst_detection(r,d,n,s=param_s, gamma=param_gamma, smooth_win=1)
    
    """
    bursts = bd.enumerate_bursts(q, 'burstLabel')
    
    #find weight of bursts
    weighted_bursts = bd.burst_weights(bursts,r,d,p)
    
    print('observed probabilities: ') 
    print(str(r/d) )
    print( 'optimal state sequence: ')
    print(str(q.T) )
    print( 'baseline probability: ' + str(p[0]) )
    print( 'bursty probability: ' + str(p[1]) )
    """
    
    return(q)

# %% [markdown]
# ### 見頃plot

# %%
from matplotlib import pyplot as plt
from matplotlib import dates as mdates
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
from matplotlib.dates import date2num

def plot_migoro(dates, q, pref, flag, rate):
    
    if flag == "sakura":
        x = dates[0:90]
        q = q[0:90]
    else: 
        x = dates
    
    y_correct = []
    if flag == "sakura":
        for date in x:
            if CORRECTS[pref][flag]['start'] <= date <= CORRECTS[pref][flag]['end']:
                y_correct.append(1)
            else:
                y_correct.append(0)
    elif flag == "sonota" or flag == "koyo" or flag == "jumoku":
        for date in x:
            if ( CORRECTS[pref]["kaede"]['start'] <= date <= CORRECTS[pref]["kaede"]['end']
                or CORRECTS[pref]["icho"]['start'] <= date <= CORRECTS[pref]["icho"]['end']):
                y_correct.append(1)
            else:
                y_correct.append(0)
    else: 
        for date in x:
            if  CORRECTS[pref][flag]['start'] <= date <= CORRECTS[pref][flag]['end']:
                y_correct.append(1)
            else: 
                 y_correct.append(0)
                    
    figure_ = plt.figure()  # Figure作成
    figure_.text(0.2, 0.5, str(pref) + ": " + str(flag), fontsize=20)
    figure_.text(0.2, 0.4, "rate = " + str(rate), fontsize=20)
    
    axes_ = figure_.add_subplot(111)  # Axes作成
    xaxis_ = axes_.xaxis  # XAxis取得
    
    x_numdate = date2num([
        dt.date(2015, 8, 15), 
        dt.date(2015, 9, 1), dt.date(2015, 9, 15), 
        dt.date(2015, 10, 1), dt.date(2015, 10, 15), 
        dt.date(2015, 11, 1), dt.date(2015, 11, 15), 
        dt.date(2015, 12, 1), dt.date(2015, 12, 15), dt.date(2015, 12, 31)
    ])
    if flag == "sakura":
        x_numdate = date2num([
        dt.date(2015, 2, 17), 
        dt.date(2015, 3, 15), dt.date(2015, 4, 1), 
        dt.date(2015, 4, 15), dt.date(2015, 5, 1), 
        dt.date(2015, 5, 15)
    ])
    
    axes_.xaxis.set_major_locator(ticker.FixedLocator(x_numdate))
    axes_.tick_params(axis='x', rotation=270)
    xaxis_.set_major_formatter(DateFormatter('%m-%d'))
    
    axes_.plot(x, y_correct, label='correct')
    axes_.plot(x, q, label='burst')
    plt.legend()
    

    fname = f"{flag}_{str(rate).zfill(3)}.png"
    
    os.makedirs(out_path + f"{pref}/", exist_ok=True)
    plt.savefig(out_path + f"{pref}/" + fname, format="png", dpi=300)
    plt.show()
    
    plt.close()

# %% [markdown]
# ### F値算出<br>evaluate(result, pref, flag)

# %%
def evaluate(result, pref, flag):        
    """
    tp: true positives
    tn: true negatives
    fn: false negativess
    fp: false positives
    """
    tp, tn, fn, fp = 0, 0, 0, 0
    if flag in ["icho", "kaede"]:
        correct_period = [date for date in date_range(CORRECTS[pref][flag]['start'], \
                                                      CORRECTS[pref][flag]['end'])]
    elif flag in ["jumoku", "sonota", "koyo"]: 
        icho_period = [date for date in date_range(CORRECTS[pref]['icho']['start'], \
                                                      CORRECTS[pref]['icho']['end'])]
        kaede_period = [date for date in date_range(CORRECTS[pref]['kaede']['start'], \
                                                      CORRECTS[pref]['kaede']['end'])]
        
        correct_period = icho_period + kaede_period
        correct_period = list(set(correct_period))
    elif flag in ["sakura"]:
        correct_period = [date for date in date_range(CORRECTS[pref][flag]['start'], \
                                                      CORRECTS[pref][flag]['end'])]
        

    for oneday in dates:
        if oneday in correct_period:
            if result[result['date']==oneday].iloc[0, 1][0] == 1:
                tp += 1
            elif result[result['date']==oneday].iloc[0, 1][0] == 0:
                tn += 1
            else:
                print("error")
        else:
            if result[result['date']==oneday].iloc[0, 1][0] == 1:
                fp += 1
            elif result[result['date']==oneday].iloc[0, 1][0] == 0:
                fn += 1
            else:
                print("error")
    
    if tp == 0:
        recall = precision = fscore = 0
    else:
        recall = tp / len(correct_period)
        precision = tp / (tp + fp)
        fscore = (2 * recall * precision) / (recall + precision)
    
    # 評価値を出す
#     print(f"recall: {recall}")
#     print(f"precision: {precision}")
    print(f"F-score: {fscore}")
    
    return recall, precision, fscore

# %% [markdown]
# ### F値plot<br>plot_fscores(fscores, rates, pref, flag):

# %%
def plot_fscores(fscores, rates, pref, flag):
    figure_ = plt.figure()  # Figure作成
    axes_ = figure_.add_subplot(111)  # Axes作成
    axes_.plot(rates, fscores, label='fscores')
    
#     out_dir = f"{RESULT_DIR}graph/s{param_s}gamma{param_gamma}/{pref}/"
    fname = f"fscores_{flag}.png"
    
    plt.savefig(out_path + f"{pref}/" + fname, format="png", dpi=300)
    plt.show()
    
    plt.close()

# %% [markdown]
# ### F値すべてplot<br>plot_all_fscores(results, pref):

# %%
def plot_all_fscores(results, pref):
    figure_ = plt.figure()  # Figure作成
    axes_ = figure_.add_subplot(111)  # Axes作成
    
#     flags = ["icho", "kaede", "sonota", "koyo", "jumoku"]
    for flag in flags:
        axes_.plot(RATES, results.query(f"flag == '{flag}'")["fscore"], label=flag)
    
#     out_dir = f"{RESULT_DIR}graph/s{param_s}gamma{param_gamma}/{pref}/"
    fname = f"all_fscores_{pref}.png"
    
    plt.legend()
    plt.savefig(out_path + f"{pref}/" + fname, format="png", dpi=300)
    plt.show()
    
    plt.close()

# %% [markdown]
# # main関数

# %% [markdown]
# ### ファイル読み込み

# %%
target_counts = dict()
total_counts = dict()

for pref in prefs:
    target_counts[pref] = {}
    for flag in flags:
        target_counts[pref].update({flag: [ [], [], [], [], [], [], [], [], [], [] ]})
        
target_counts[prefs[0]]
# Out:
# {'icho': [[], [], [], [], [], [], [], [], [], []]}

# %%
for pref, flag in  itertools.product(prefs, flags):
    for i, rate in enumerate(RATES):
        filename = f"{pref}_{flag}_{str(rate).zfill(3)}rwords_count.txt"
        with open(rtweets_count_dir+filename, "r") as target_file:
             target_counts[pref][flag][i] = [line.rstrip('\n').split('\t')[1] for line in target_file.readlines()]

total_counts = {}   
for pref in prefs:
    fname = pref + "_total_dailycount.txt"
    total_counts[pref] = pd.read_csv(total_count_dir + fname, names=("date", "count"), header=None, sep='\t')

# %% [markdown]
# ### 処理部

# %%
results = pd.DataFrame(columns=["pref", "flag", "rate", "recall", "precision", "fscore"])
max_score = pd.DataFrame(0.0, columns=prefs, index=flags)
best_rate = pd.DataFrame(0, columns=prefs, index=flags)

for pref, flag in itertools.product(prefs, flags):
    print(f"{pref} -------------{flag}")
    for i, rate in enumerate(RATES):
        
        if flag == "sakura":
            q = burst_detection(target_counts[pref][flag][i], total_counts[pref]["count"] )
        else:
            total = list(total_counts[pref].query("date >= '2015-08-15'")["count"].values)
            target = target_counts[pref][flag][i]
            if np.all(np.array(target) == '0'): # targetが全て0だとburst_detectionがエラーになる。
                q = []
                for i in range(len(target)):
                    q.append([0.0])
            else:
                q = burst_detection(target, total)
                
        if flag == "sakura":
            dates = sakura_dates
        else:
            dates = koyo_long_dates

        plot_migoro(dates, q, pref, flag, rate)
        
        
        q_dateframe = pd.DataFrame([dates, q]).T
        
        q_dateframe.columns = ['date', 'burst']
        recall, precision, fscore = evaluate(q_dateframe, pref, flag)
        
        if  fscore >= max_score[pref][flag]:
            if fscore == max_score[pref][flag] and fscore != 0:
                print("Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して")
            max_score.at[flag, pref] = fscore
            best_rate.at[flag, pref] = rate
        
        result = pd.Series([pref, flag, rate, recall, precision, fscore], index=results.columns)
        results = results.append(result, ignore_index=True)
        
    if len(flags) == 5:
        plot_fscores(results.query(f"pref == '{pref}' and flag == '{flag}'")["fscore"], RATES, pref, flag)       
print("---------\n終了\n---------\n")
# Out:
# tk -------------icho
# F-score: 0.5581395348837209
# F-score: 0.5714285714285715
# F-score: 0.5714285714285715
# Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# F-score: 0.5581395348837209
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# hk -------------icho
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# is -------------icho
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# ---------
# 終了
# ---------

# %%
for pref in prefs:
    plot_all_fscores(results.query(f"pref == '{pref}'"), pref)

# %%
# os.makedirs(path, exist_ok=True)
# results.to_csv(out_path+"result.tsv", sep='\t')

pd.set_option('display.max_rows', 500)
display(results)
# Out:
#    pref  flag rate  recall  precision    fscore
# 0    tk  icho   10     1.0   0.387097  0.558140
# 1    tk  icho   20     1.0   0.400000  0.571429
# 2    tk  icho   30     1.0   0.400000  0.571429
# 3    tk  icho   40     1.0   0.352941  0.521739
# 4    tk  icho   50     1.0   0.352941  0.521739
# 5    tk  icho   60     1.0   0.387097  0.558140
# 6    tk  icho   70     1.0   0.352941  0.521739
# 7    tk  icho   80     1.0   0.352941  0.521739
# 8    tk  icho   90     1.0   0.352941  0.521739
# 9    tk  icho  100     1.0   0.352941  0.521739
# 10   hk  icho   10     0.0   0.000000  0.000000
# 11   hk  icho   20     0.0   0.000000  0.000000
# 12   hk  icho   30     0.0   0.000000  0.000000
# 13   hk  icho   40     0.0   0.000000  0.000000
# 14   hk  icho   50     0.0   0.000000  0.000000
# 15   hk  icho   60     0.0   0.000000  0.000000
# 16   hk  icho   70     0.0   0.000000  0.000000
# 17   hk  icho   80     0.0   0.000000  0.000000
# 18   hk  icho   90     0.0   0.000000  0.000000
# 19   hk  icho  100     0.0   0.000000  0.000000
# 20   is  icho   10     0.0   0.000000  0.000000
# 21   is  icho   20     0.0   0.000000  0.000000
# 22   is  icho   30     0.0   0.000000  0.000000
# 23   is  icho   40     0.0   0.000000  0.000000
# 24   is  icho   50     0.0   0.000000  0.000000
# 25   is  icho   60     0.0   0.000000  0.000000
# 26   is  icho   70     0.0   0.000000  0.000000
# 27   is  icho   80     0.0   0.000000  0.000000
# 28   is  icho   90     0.0   0.000000  0.000000
# 29   is  icho  100     0.0   0.000000  0.000000

# %%
# gamma: 
# 基本的に値が高ければ高いほど、バーストが立ち上がりにくくなるパラメータなのでこれの調整の優先度は低いと思います。
# とりあえずgamma＝1とかに設定しておくのがいいです。
# s: 
# 値が高ければ高いほど、バーストが分割される傾向にあるので、1.1~2の範囲で試してみるのがいいかも
param_s = 1.5# 2.0
param_gamma = 1.0 # 1.0

RESULT_DIR = "/Users/daigo/workspace/koyo/result/"
total_count_dir = RESULT_DIR + "total_count/"
rtweets_count_dir = RESULT_DIR + "rtweets_count/"

out_path = f"{RESULT_DIR}graph/koyo_de_icho/s{param_s}gamma{param_gamma}/"
# out_path = f"{RESULT_DIR}graph/uniq_icho/s{param_s}gamma{param_gamma}/"
# out_path = f"{RESULT_DIR}graph/sakura/s{param_s}gamma{param_gamma}/"
# sakura を推定するときはout_path注意。

RATES = range(10, 101, 10)
prefs = ['tk', 'hk', 'is'] # ['tk', 'hk', 'is']
flags = ["icho"]  # ["icho", "kaede", "sonota", "koyo", "jumoku"] , "sakura"

# %%
target_counts = dict()
total_counts = dict()

for pref in prefs:
    target_counts[pref] = {}
    for flag in flags:
        target_counts[pref].update({"koyo": [ [], [], [], [], [], [], [], [], [], [] ]})
        
target_counts[prefs[0]]
# Out:
# {'koyo': [[], [], [], [], [], [], [], [], [], []]}

# %%
for pref, flag in  itertools.product(prefs, flags):
    for i, rate in enumerate(RATES):
        filename = f"{pref}_koyo_{str(rate).zfill(3)}rwords_count.txt"
        with open(rtweets_count_dir+filename, "r") as target_file:
             target_counts[pref]["koyo"][i] = [line.rstrip('\n').split('\t')[1] for line in target_file.readlines()]

total_counts = {}   
for pref in prefs:
    fname = pref + "_total_dailycount.txt"
    total_counts[pref] = pd.read_csv(total_count_dir + fname, names=("date", "count"), header=None, sep='\t')

# %% [markdown]
# ### 処理部

# %%
results = pd.DataFrame(columns=["pref", "flag", "rate", "recall", "precision", "fscore"])
max_score = pd.DataFrame(0.0, columns=prefs, index=flags)
best_rate = pd.DataFrame(0, columns=prefs, index=flags)

for pref, flag in itertools.product(prefs, flags):
    print(f"{pref} -------------{flag}")
    for i, rate in enumerate(RATES):
        
        if flag == "sakura":
            q = burst_detection(target_counts[pref]["koyo"][i], total_counts[pref]["count"] )
        else:
            total = list(total_counts[pref].query("date >= '2015-08-15'")["count"].values)
            target = target_counts[pref]["koyo"][i]
            if np.all(np.array(target) == '0'): # targetが全て0だとburst_detectionがエラーになる。
                q = []
                for i in range(len(target)):
                    q.append([0.0])
            else:
                q = burst_detection(target, total)
                
        if flag == "sakura":
            dates = sakura_dates
        else:
            dates = koyo_long_dates

        plot_migoro(dates, q, pref, flag, rate)
        
        
        q_dateframe = pd.DataFrame([dates, q]).T
        
        q_dateframe.columns = ['date', 'burst']
        recall, precision, fscore = evaluate(q_dateframe, pref, flag)
        
        if  fscore >= max_score[pref][flag]:
            if fscore == max_score[pref][flag] and fscore != 0:
                print("Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して")
            max_score.at[flag, pref] = fscore
            best_rate.at[flag, pref] = rate
        
        result = pd.Series([pref, flag, rate, recall, precision, fscore], index=results.columns)
        results = results.append(result, ignore_index=True)
        

    plot_fscores(results.query(f"pref == '{pref}' and flag == '{flag}'")["fscore"], RATES, pref, flag)       
print("---------\n終了\n---------\n")
# Out:
# tk -------------icho
# F-score: 0.5454545454545454
# F-score: 0.5581395348837209
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# F-score: 0.5581395348837209
# Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して
# F-score: 0.5581395348837209
# Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して
# F-score: 0.5333333333333333
# F-score: 0.5217391304347826
# F-score: 0.5217391304347826
# F-score: 0.5106382978723404
# hk -------------icho
# F-score: 0
# F-score: 0
# F-score: 0.6206896551724137
# F-score: 0.6206896551724137
# Maxfscoreが等しい条件があります。このMaxが上書きされなければ、書き直して
# F-score: 0.43902439024390244
# F-score: 0
# F-score: 0.43902439024390244
# F-score: 0.43902439024390244
# F-score: 0
# F-score: 0.2222222222222222
# is -------------icho
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# F-score: 0
# ---------
# 終了
# ---------

# %% [markdown]
# ### テスト

# %% [markdown]
# **target_countsの構造**
#
# ```
# target_counts{
#     pref: {
#         flag: [] # 要素数10でrate10~100のrtweet_countが入っている。
#     }
# }
# ```

# %%
plot_fscores(results.query(f"pref == 'tk' and flag == 'icho'")["fscore"], RATES, "tk", "icho")

# %%
plot_fscores(results_icho.query(f"pref == 'tk' and flag == 'icho'")["fscore"], RATES, "tk", "icho")

# %%
# os.makedirs(path, exist_ok=True)
# results.to_csv(out_path+"result.tsv", sep='\t')

pd.set_option('display.max_rows', 500)
display(results_icho)
# Out:
#    pref  flag rate  recall  precision    fscore
# 0    tk  icho   10     1.0   0.400000  0.571429
# 1    tk  icho   20     1.0   0.387097  0.558140
# 2    tk  icho   30     1.0   0.387097  0.558140
# 3    tk  icho   40     1.0   0.400000  0.571429
# 4    tk  icho   50     1.0   0.363636  0.533333
# 5    tk  icho   60     1.0   0.363636  0.533333
# 6    tk  icho   70     1.0   0.387097  0.558140
# 7    tk  icho   80     1.0   0.352941  0.521739
# 8    tk  icho   90     1.0   0.352941  0.521739
# 9    tk  icho  100     1.0   0.352941  0.521739
# 10   hk  icho   10     0.0   0.000000  0.000000
# 11   hk  icho   20     0.0   0.000000  0.000000
# 12   hk  icho   30     0.0   0.000000  0.000000
# 13   hk  icho   40     0.0   0.000000  0.000000
# 14   hk  icho   50     0.0   0.000000  0.000000
# 15   hk  icho   60     0.0   0.000000  0.000000
# 16   hk  icho   70     0.0   0.000000  0.000000
# 17   hk  icho   80     0.0   0.000000  0.000000
# 18   hk  icho   90     0.0   0.000000  0.000000
# 19   hk  icho  100     0.0   0.000000  0.000000
# 20   is  icho   10     0.0   0.000000  0.000000
# 21   is  icho   20     0.0   0.000000  0.000000
# 22   is  icho   30     0.0   0.000000  0.000000
# 23   is  icho   40     0.0   0.000000  0.000000
# 24   is  icho   50     0.0   0.000000  0.000000
# 25   is  icho   60     0.0   0.000000  0.000000
# 26   is  icho   70     0.0   0.000000  0.000000
# 27   is  icho   80     0.0   0.000000  0.000000
# 28   is  icho   90     0.0   0.000000  0.000000
# 29   is  icho  100     0.0   0.000000  0.000000

# %%
CORRECTS = {
    "tk": {
        "kaede": {"start": dt.date(2015, 12, 4), "end": dt.date(2015, 12, 12)},
        "icho": {"start": dt.date(2015, 11, 30), "end": dt.date(2015, 12, 11)},
        "sakura": {"start": dt.date(2015, 3, 23), "end": dt.date(2015, 3, 29)}
    },
    "hk": {
        "kaede": {"start": dt.date(2015, 10, 29), "end": dt.date(2015, 11, 29)},
        "icho": {"start": dt.date(2015, 11, 2), "end": dt.date(2015, 11, 12)},
        "sakura": {"start": dt.date(2015, 4, 22), "end": dt.date(2015, 4, 26)}
    },
    "is": {
        "kaede": {"start": dt.date(2015, 11, 22), "end": dt.date(2015, 12, 3)},
        "icho": {"start": dt.date(2015, 11, 4), "end": dt.date(2015, 11, 10)},
        "sakura": {"start": dt.date(2015, 3, 31), "end": dt.date(2015, 4, 4)}
    }
}

# %%
prefs = ["tk", "hk","is"]
flags = ["icho", "kaede"]

for pref in prefs:
    for flag in flags:
        print(f"correct_dates['{pref}']['{flag}']= [pd.to_datetime(date) for date in pd.date_range(start='{CORRECTS[pref][flag]['start']}', end='{CORRECTS[pref][flag]['end']}', tz='Japan', freq='D')]")
# Out:
# correct_dates['tk']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-30', end='2015-12-11', tz='Japan', freq='D')]
# correct_dates['tk']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-12-04', end='2015-12-12', tz='Japan', freq='D')]
# correct_dates['hk']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-02', end='2015-11-12', tz='Japan', freq='D')]
# correct_dates['hk']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-10-29', end='2015-11-29', tz='Japan', freq='D')]
# correct_dates['is']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-04', end='2015-11-10', tz='Japan', freq='D')]
# correct_dates['is']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-22', end='2015-12-03', tz='Japan', freq='D')]

# %%
correct_dates['tk']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-30', end='2015-12-11', tz='Japan', freq='D')]
correct_dates['tk']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-12-04', end='2015-12-12', tz='Japan', freq='D')]
correct_dates['hk']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-02', end='2015-11-12', tz='Japan', freq='D')]
correct_dates['hk']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-10-29', end='2015-11-29', tz='Japan', freq='D')]
correct_dates['is']['icho']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-04', end='2015-11-10', tz='Japan', freq='D')]
correct_dates['is']['kaede']= [pd.to_datetime(date) for date in pd.date_range(start='2015-11-22', end='2015-12-03', tz='Japan', freq='D')]

# %%
rwords_path = "../result/related_words_with_count/"
result_path = "../result/for_noise/"
rwords_path = "/Users/daigo/workspace/koyo/result/related_words_with_count/"

# %%
for pref in prefs:
    for flag in flags:
        df = pd.DataFrame(columns=["word", "noise", "s_count", "y_count"])

        fname = f"{flag}_{pref}_4soa.txt"
        rwords = pd.read_csv(
            rwords_path+fname,
            names=('word', 'soa', 'season', 'non_season', 'total'),
            header=None
            )
rwords
# Out:
#    word        soa  season  non_season  total
# 0   あゆみ  12.994707       1           0      1
# 1   さゆみ  12.994707       1           0      1
# 2   2年間  12.994707       1           0      1
# 3   定食屋  12.994707       1           0      1
# 4  野々市市   7.824782       1          35     36
# 5    AT   4.850049       1         282    283
# 6    Im   4.518974       1         355    356
# 7   石川県   4.149217       1         459    460
# 8    in   4.124342       1         467    468

# %%
rwords["word"].values.tolist()[0]
# Out:
# 'あゆみ'

# %%
df = pd.DataFrame(columns=["word", "noise", "s_count", "y_count"])

# %%
df
# Out:
# Empty DataFrame
# Columns: [word, noise, s_count, y_count]
# Index: []

# %%
s = pd.Series([ "hoge", 1, 2, 3], 
              index=["word", "noise", "s_count", "y_count"])
s
# Out:
# word       hoge
# noise         1
# s_count       2
# y_count       3
# dtype: object

# %%
df.append(s, ignore_index=True)
# Out:
#    word noise s_count y_count
# 0  hoge     1       2       3
